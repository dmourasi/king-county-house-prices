# %% [markdown]
# # Generalização (item 2.2) — versão Python
#
# Versão Python de [`analysis/02-2_generalizacao.qmd`](../analysis/02-2_generalizacao.qmd). No notebook de modelagem (`02-1_modelagem.ipynb`) escolhi **XGBoost** como modelo final, depois de comparar 6 modelos — mas só decidi adotá-lo depois de rodar exatamente as checagens deste notebook nos dois principais candidatos (XGBoost e Random Forest) e confirmar que a vantagem do XGBoost sobrevive à mais rigorosa delas. Aqui documento a bateria completa, no modelo já escolhido, respondendo três perguntas que a validação básica do item 2.1 não responde:
#
# 1. **O RMSE de teste é um número exato ou tem incerteza?** → bootstrap.
# 2. **O split aleatório está sendo generoso demais?** → split temporal.
# 3. **O modelo generaliza para um CEP que nunca viu?** → validação cruzada agrupada por `zipcode`.

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split, GroupKFold
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

DATA = "../data"
pd.set_option("display.float_format", lambda x: f"{x:,.4f}")

# %% [markdown]
# ## 1. Reconstruindo o dataset e o split (mesma preparação de `02-1_modelagem.ipynb`)
#
# Repito a preparação de dados e uso o mesmo `random_state=42` e a mesma estratificação — então `X_train`/`X_test` aqui são exatamente o mesmo split usado para treinar e avaliar o modelo salvo, permitindo reaproveitá-lo sem retreinar.

# %%
casas = pd.read_csv(f"{DATA}/kc_house_data.csv")
casas["date"] = pd.to_datetime(casas["date"], format="%Y%m%dT%H%M%S")
casas = casas[casas["bedrooms"] < 30].copy()

demograf = pd.read_csv(f"{DATA}/zipcode_demographics.csv")

casas["log_price"] = np.log(casas["price"])
casas["tem_porao"] = (casas["sqft_basement"] > 0).astype(int)
casas["idade_casa"] = casas["date"].dt.year - casas["yr_built"]
casas["reformado"] = (casas["yr_renovated"] > 0).astype(int)
casas = casas.merge(demograf, on="zipcode", how="left")

vars_modelo = ["bedrooms", "bathrooms", "sqft_living", "sqft_lot", "floors",
    "waterfront", "view", "condition", "grade", "tem_porao", "idade_casa", "reformado",
    "lat", "long", "sqft_living15", "sqft_lot15",
    "medn_hshld_incm_amt", "medn_incm_per_prsn_amt", "hous_val_amt", "per_bchlr", "per_prfsnl"]

X = casas[vars_modelo]
y = casas["log_price"]
bins = pd.qcut(y, q=10, labels=False, duplicates="drop")

idx_treino, idx_teste = train_test_split(casas.index, test_size=0.2, random_state=42, stratify=bins)
casas_treino = casas.loc[idx_treino]
casas_teste = casas.loc[idx_teste]

def metricas(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    return pd.Series({"rmse": rmse, "mae": mae, "r2": r2})

modelo_xgb = joblib.load("models/modelo_xgb.joblib")
pred_teste = modelo_xgb.predict(casas_teste[vars_modelo])
real_teste = casas_teste["log_price"].values
metricas(real_teste, pred_teste)
# Out:
# rmse   0.1615
# mae    0.1154
# r2     0.9069
# dtype: float64

# %% [markdown]
# ## 2. Quanta incerteza tem o RMSE de teste?
#
# *Bootstrap*: reamostro as mesmas previsões de teste, com reposição, 2.000 vezes, recalculando a métrica a cada vez — isso não usa dado novo, usa a variação natural de "que teste eu teria tido se o sorteio tivesse saído diferente" para construir um intervalo em vez de um único número.

# %%
rng = np.random.default_rng(123)
n_teste = len(real_teste)
boot_rmse = np.empty(2000)
boot_mae = np.empty(2000)

for b in range(2000):
    idx_boot = rng.integers(0, n_teste, n_teste)
    boot_rmse[b] = np.sqrt(mean_squared_error(real_teste[idx_boot], pred_teste[idx_boot]))
    boot_mae[b] = mean_absolute_error(real_teste[idx_boot], pred_teste[idx_boot])

pd.DataFrame({
    "metrica": ["rmse", "mae"],
    "estimado_pontual": [np.sqrt(mean_squared_error(real_teste, pred_teste)), mean_absolute_error(real_teste, pred_teste)],
    "ic_95_inferior": [np.percentile(boot_rmse, 2.5), np.percentile(boot_mae, 2.5)],
    "ic_95_superior": [np.percentile(boot_rmse, 97.5), np.percentile(boot_mae, 97.5)],
})
# Out:
#   metrica  estimado_pontual  ic_95_inferior  ic_95_superior
# 0    rmse            0.1615          0.1557          0.1676
# 1     mae            0.1154          0.1122          0.1188

# %% [markdown]
# Intervalo estreito — o RMSE de teste é estável, não é sorte de um sorteio específico de teste.

# %% [markdown]
# ## 3. Split aleatório vs. split temporal
#
# Um split aleatório mistura vendas "do futuro" e "do passado" entre treino e teste — algo que nunca vai acontecer numa produção real, onde sempre se prevê o futuro a partir do passado. Refaço o split ordenando por data e usando as primeiras 80% das vendas como treino.
#
# Uso `max_depth` igual ao modelo final (escolhido por CV no item 2.1), mas fixo nos dois lados desta comparação, pra que a única diferença entre as duas linhas seja a forma do split, não o hiperparâmetro.

# %%
casas_ordenado = casas.sort_values("date")
corte = int(0.8 * len(casas_ordenado))
treino_temporal = casas_ordenado.iloc[:corte]
teste_temporal = casas_ordenado.iloc[corte:]

print("treino:", treino_temporal["date"].min().date(), "a", treino_temporal["date"].max().date())
print("teste: ", teste_temporal["date"].min().date(), "a", teste_temporal["date"].max().date())

max_depth_final = modelo_xgb.max_depth

def treinar_xgb(X_tr, y_tr):
    return XGBRegressor(max_depth=max_depth_final, learning_rate=0.1, n_estimators=300,
                         objective="reg:squarederror", n_jobs=-1, random_state=42, verbosity=0).fit(X_tr, y_tr)

modelo_temporal = treinar_xgb(treino_temporal[vars_modelo], treino_temporal["log_price"])
pred_temporal = modelo_temporal.predict(teste_temporal[vars_modelo])

modelo_aleatorio_ref = treinar_xgb(casas_treino[vars_modelo], casas_treino["log_price"])
pred_aleatorio_ref = modelo_aleatorio_ref.predict(casas_teste[vars_modelo])

pd.DataFrame({
    "split temporal": metricas(teste_temporal["log_price"], pred_temporal),
    "split aleatório (ref)": metricas(casas_teste["log_price"], pred_aleatorio_ref),
}).T
# Out:
# treino: 2014-05-02 a 2015-03-10
# teste:  2015-03-10 a 2015-05-27
#                         rmse    mae     r2
# split temporal        0.1825 0.1356 0.8763
# split aleatório (ref) 0.1615 0.1154 0.9069

# %% [markdown]
# O split temporal piora o RMSE em relação ao aleatório — confirma com número real a preocupação de que parte do desempenho reportado vem de o teste ter imóveis "intercalados" no tempo com o treino, algo que não se repete em produção.

# %% [markdown]
# ## 4. E se aparecer um CEP que o modelo nunca viu?
#
# Diferente de uma CV comum (que sorteia *linhas*, deixando o mesmo CEP presente nos dois lados), sorteio *zipcodes inteiros* em 5 grupos com `GroupKFold` — cada fold testa em CEPs 100% ausentes do treino daquele fold. Isso simula "apareceu uma casa num bairro que o modelo nunca viu". **Esta foi a checagem decisiva** que me convenceu a trocar de Random Forest para XGBoost (ver item 2.1) — rodei os dois modelos aqui antes de decidir.

# %%
gkf = GroupKFold(n_splits=5)
resultados_grupo = []

for fold, (idx_tr, idx_te) in enumerate(gkf.split(X, y, groups=casas["zipcode"])):
    modelo_g = treinar_xgb(X.iloc[idx_tr], y.iloc[idx_tr])
    pred_g = modelo_g.predict(X.iloc[idx_te])
    m = metricas(y.iloc[idx_te], pred_g)
    resultados_grupo.append({
        "fold": fold, "rmse": m["rmse"], "mae": m["mae"], "r2": m["r2"],
        "n_zipcodes_teste": casas["zipcode"].iloc[idx_te].nunique(), "n_obs_teste": len(idx_te),
    })

resultados_grupo = pd.DataFrame(resultados_grupo)
resultados_grupo
# Out:
#    fold   rmse    mae     r2  n_zipcodes_teste  n_obs_teste
# 0     0 0.2155 0.1590 0.8428                14         4339
# 1     1 0.2161 0.1603 0.8672                14         4325
# 2     2 0.2038 0.1502 0.8116                14         4306
# 3     3 0.1654 0.1211 0.8719                14         4343
# 4     4 0.1720 0.1269 0.8933                14         4299

# %%
resultados_grupo[["rmse", "mae", "r2"]].agg(["mean", "std"])
# Out:
#        rmse    mae     r2
# mean 0.1946 0.1435 0.8574
# std  0.0242 0.0183 0.0312

# %% [markdown]
# ## 5. Síntese

# %%
sintese = pd.DataFrame({
    "split aleatório (modelo final)": metricas(real_teste, pred_teste),
    "split aleatório (ref, mesmos hiperparâmetros)": metricas(casas_teste["log_price"], pred_aleatorio_ref),
    "split temporal": metricas(teste_temporal["log_price"], pred_temporal),
    "CV agrupada por CEP (média dos 5 folds)": resultados_grupo[["rmse", "mae", "r2"]].mean(),
}).T
sintese["variacao_rmse_vs_aleatorio"] = sintese["rmse"] / sintese.loc["split aleatório (modelo final)", "rmse"] - 1
sintese
# Out:
#                                                 rmse    mae     r2  \
# split aleatório (modelo final)                0.1615 0.1154 0.9069
# split aleatório (ref, mesmos hiperparâmetros) 0.1615 0.1154 0.9069
# split temporal                                0.1825 0.1356 0.8763
# CV agrupada por CEP (média dos 5 folds)       0.1946 0.1435 0.8574
#
#                                                variacao_rmse_vs_aleatorio
# split aleatório (modelo final)                                     0.0000
# split aleatório (ref, mesmos hiperparâmetros)                      0.0000
# split temporal                                                     0.1300
# CV agrupada por CEP (média dos 5 folds)                            0.2046

# %% [markdown]
# O padrão se repete: **a maior ameaça à generalização não é o tempo, é o bairro novo** — o RMSE da CV agrupada por CEP piora bem mais que o do split temporal (~20% contra ~13%, nos números que já vi ao decidir o modelo no item 2.1).
#
# Vale registrar o que essa checagem mudou na minha decisão: quando testei a mesma bateria na Random Forest (a implementação anterior, ainda documentada em `models/modelo_rf.joblib` e na versão R do projeto), a degradação em CEP novo também apareceu — e, nesse teste específico, um pouco **maior** proporcionalmente do que a do XGBoost. Ou seja, o XGBoost não só parte de um erro menor, como se mostrou pelo menos tão robusto (senão mais) à generalização geográfica — o que descartou minha principal hesitação em trocar de modelo depois de já ter validado a Random Forest.
#
# Essa mesma ordem de risco (CEP novo > tempo) já tinha aparecido de forma independente nas duas linguagens quando o modelo era Random Forest — reforça que não é um artefato de uma ferramenta específica, é uma característica real dos dados e das features escolhidas (não usar `zipcode` como categoria, só `lat`/`long` + demografia). Não refiz essa réplica cruzada de linguagem especificamente para o XGBoost; fica registrado como algo que valeria fazer numa próxima iteração.
